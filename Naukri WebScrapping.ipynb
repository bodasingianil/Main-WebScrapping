# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np

import traceback
import logging

# Set up basic logging configuration
logging.basicConfig(
    level=logging.INFO,                     # Set the logging level to INFO
    format='%(asctime)s - %(levelname)s - %(message)s',  # Customize the log format
    handlers=[logging.StreamHandler()]      # Ensure logs are sent to the console (Jupyter output)
)

# %%
def get_jobs_data(df, bs_data):

    all_jobs = bs_data.find_all("div", attrs={"class": "cust-job-tuple layout-wrapper lay-2 sjw__tuple"})  # main container holds list of jobs

    for each_job in all_jobs:
        job_info = {}  # Creating the empty Dictionary
        
        try:
            job_info['title'] = each_job.find("div", attrs={"class": "row1"}).text
        except:
            job_info['title'] = np.nan
        
        company_details = each_job.find("div", attrs={"class": "row2"}).find_all("a", attrs={})
        
        try:
            job_info['companyName'] = company_details[0].text
        except:
            job_info['companyName'] = np.nan
        
        try:
            job_info['rating'] = company_details[1].text
        except:
            job_info['rating'] = np.nan
        
        try: 
            job_info['reviews'] = company_details[2].text
        except:
            job_info['reviews'] = np.nan
        
        other_details = each_job.find("div", attrs={"class": "row3"}).find_all("span", attrs={})
        
        try:    
            job_info['experience'] = other_details[2].text.strip()
        except:
            job_info['experience'] = np.nan
        
        try:    
            job_info['salary'] = other_details[4].text.strip()
        except:
            job_info['salary'] = np.nan
        
        try:
            job_info['location'] = other_details[6].text.strip()
        except:
            job_info['location'] = np.nan
        
        try:
            job_info['qualification_required'] = each_job.find("div", attrs={"class": "row4"}).text
        except:
            job_info['qualification_required'] = np.nan
        
        tags = each_job.find("div", attrs={"class": "row5"}).find_all("li", attrs={"class": "dot-gt tag-li"})
        
        try:
            job_info['skills'] = ",".join([tag.text.strip() for tag in tags])
        except:
            job_info['skills'] = np.nan
        
        try:
            job_info['day_posted'] = each_job.find("div", attrs={"class": "row6"}).text
        except:
            job_info['day_posted'] = np.nan
            
        each_df = pd.DataFrame(job_info, index=[0])
        df = pd.concat((df, each_df), ignore_index=True)
        
    return df

# %%
# Initialize DataFrame
df = pd.DataFrame()

# Set up Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

service = Service(r"C:\Users\sweth\Desktop\Innomatics\ClassRoom\WebScraping\Latest\chromedriver.exe")

try:
    
    driver = webdriver.Chrome(service=service, options=chrome_options)
    logging.info("WebDriver initialized successfully.")
    
    roles = ["Data Scientist", "Data Analyst", "Data Engineer", "Python Developer"]
    for each_role in roles:
        each_role.replace(" ", "+")
        
        for each_page in range(1,21):
            try:
                page_link = f"https://www.naukri.com/{each_role}-jobs-{each_page}?k={each_role}&nignbevent_src=jobsearchDeskGNB"
                
                logging.info(f"Processing page {each_page}")
                logging.info(f"Page link: {page_link}")
                
                driver.get(page_link)
                
                # Let the page load completely
                time.sleep(5)
                
                logging.info("Parsing the page source with BeautifulSoup")
                bs_data = BeautifulSoup(driver.page_source, 'html.parser')

                # Executing get_jobs_data method 
                df = get_jobs_data(df, bs_data)
                logging.info(f"Processed page {each_page} for role {each_role}")

            except Exception:
                logging.error(f"Error processing page {each_page} for role {each_role}: {traceback.format_exc()}")

except Exception as e:
    
    logging.warning(f"Failed to initialize WebDriver or process roles: {e}")
    
finally:
    
    driver.quit()
    logging.info("WebDriver closed successfully.")
# Out:
# 2024-08-28 08:46:54,728 - INFO - WebDriver initialized successfully.
# 2024-08-28 08:46:54,729 - INFO - Processing page 1
# 2024-08-28 08:46:54,730 - INFO - Page link: https://www.naukri.com/Data Scientist-jobs
- INFO - Page link: https://www.naukri.com/Python Developer-jobs-13?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:53:36,849 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:53:36,988 - INFO - Processed page 13 for role Python Developer
# 2024-08-28 08:53:36,988 - INFO - Processing page 14
# 2024-08-28 08:53:36,989 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-14?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:53:42,288 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:53:42,429 - INFO - Processed page 14 for role Python Developer
# 2024-08-28 08:53:42,430 - INFO - Processing page 15
# 2024-08-28 08:53:42,432 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-15?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:53:47,736 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:53:47,878 - INFO - Processed page 15 for role Python Developer
# 2024-08-28 08:53:47,879 - INFO - Processing page 16
# 2024-08-28 08:53:47,879 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-16?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:53:53,653 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:53:53,885 - INFO - Processed page 16 for role Python Developer
# 2024-08-28 08:53:53,887 - INFO - Processing page 17
# 2024-08-28 08:53:53,888 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-17?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:53:59,202 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:53:59,346 - INFO - Processed page 17 for role Python Developer
# 2024-08-28 08:53:59,346 - INFO - Processing page 18
# 2024-08-28 08:53:59,347 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-18?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:54:04,639 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:54:04,783 - INFO - Processed page 18 for role Python Developer
# 2024-08-28 08:54:04,784 - INFO - Processing page 19
# 2024-08-28 08:54:04,786 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-19?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:54:10,075 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:54:10,233 - INFO - Processed page 19 for role Python Developer
# 2024-08-28 08:54:10,234 - INFO - Processing page 20
# 2024-08-28 08:54:10,235 - INFO - Page link: https://www.naukri.com/Python Developer-jobs-20?k=Python Developer&nignbevent_src=jobsearchDeskGNB
# 2024-08-28 08:54:15,488 - INFO - Parsing the page source with BeautifulSoup
# 2024-08-28 08:54:15,639 - INFO - Processed page 20 for role Python Developer
# 2024-08-28 08:54:17,896 - INFO - WebDriver closed successfully.

# %%
df.to_csv(r"C:\Users\sweth\Desktop\Innomatics\ClassRoom\WebScraping\Naukri_Data_Large.csv", index=False)
df
# Out:
#                                           title                 companyName  \
# 0       Data Scientist: Artificial Intelligence                         IBM
# 1     Python Backend Developer / Data Scientist                   UBS India
# 2                Data Scientist - BLR/ HYD/ GGN                     Genpact
# 3                 Data Analyst / Data Scientist  Ifood Web Media Technology
# 4                     Hiring For Data Scientist                      Trianz
# ...                                         ...                         ...
# 1595                           Python Developer                         IBM
# 1596          Python Software Developer ( Pune)                     Infosys
# 1597                           Python Developer         HTC Global Services
# 1598                           Python Developer             Bonami Software
# 1599                           Python Developer                   Collabera
#
#                                 rating         reviews experience  \
# 0                                  4.1  20349  Reviews    5-7 Yrs
# 1                                  3.9   1320  Reviews   0-10 Yrs
# 2                                  3.9  27612  Reviews   6-11 Yrs
# 3                                  3.9     14  Reviews    5-8 Yrs
# 4                                  3.7    375  Reviews    5-8 Yrs
# ...                                ...             ...        ...
# 1595                               4.1  20349  Reviews    3-8 Yrs
# 1596                               3.8  34379  Reviews    3-8 Yrs
# 1597                               3.7   1214  Reviews    7-9 Yrs
# 1598                               4.0     69  Reviews      0 Yrs
# 1599  Posted by Collabera Technologies             NaN    3-8 Yrs
#
#                salary                                 location  \
# 0       Not disclosed                                Hyderabad
# 1       Not disclosed                                   Mumbai
# 2       Not disclosed  Hybrid - Hyderabad, Gurugram, Bengaluru
# 3       Not disclosed   Hybrid - Hyderabad, Chennai, Bengaluru
# 4      9.5-17 Lacs PA            Hybrid - Hyderabad, Bengaluru
# ...               ...                                      ...
# 1595    Not disclosed                                Ahmedabad
# 1596    Not disclosed            Hyderabad, Chennai, Bengaluru
# 1597    Not disclosed                                  Chennai
# 1598  2.5-3.5 Lacs PA                   Noida(Sector-63 Noida)
# 1599    Not disclosed                     Hyderabad, Bengaluru
#
#                                  qualification_required  \
# 0     Your Role and ResponsibilitiesWork with broade...
# 1     Overall Software development experience 8+year...
# 2     Furthermore, please do note that Genpact does ...
# 3     Highly proficient in Excel data mining, data c...
# 4     Qualifications: . Educational Background: BE /...
# ...                                                 ...
# 1595  Define, analyse, and review technical architec...
# 1596  Hiring Python Developer with experience range ...
# 1597  Proven experience across the full system devel...
# 1598  Must have hands-on experience in Data Structur...
# 1599  Experience with writing and testing Python cod...
#
#                                                  skills       day_posted
# 0     python,data analytics,artificial intelligence,...    1 Day Agosave
# 1     rest,python,software development,rdbms,natural...    1 Day Agosave
# 2     Data Science,Predictive Modeling,Decision Tree...   4 Days Agosave
# 3     Advanced Analytics,Data Analyst,Data Analytics...   5 Days Agosave
# 4     Data Science,Machine Learning,Tensorflow,GenAI...    1 Day Agosave
# ...                                                 ...              ...
# 1595  sql,api,mongodb,python development,couchdb,css...    1 Day Agosave
# 1596  Python Framework,Python Development,Python,Sof...   6 Days Agosave
# 1597  Production support,Data management,Management ...    1 Day Agosave
# 1598  Software Engineering,Django,Python,Data Struct...   6 Days Agosave
# 1599  Pyramid,Django,Python,Flask,Python Development...   7 Days Agosave
#
# [1600 rows x 10 columns]

# %%
"""
all_jobs = bs_data.find_all("div", attrs={"class": "cust-job-tuple layout-wrapper lay-2 sjw__tuple"})  # main container holds list of jobs

for each_job in all_jobs:
    job_info = {}  # Creating the empty 
    
    try:
        job_info['title'] = each_job.find("div", attrs={"class": "row1"}).text
    except:
        job_info['title'] = np.nan

    company_details = each_job.find("div", attrs={"class": "row2"}).find_all("a", attrs={})

    try:
        job_info['companyName'] = company_details[0].text
    except:
        job_info['companyName'] = np.nan

    try:
        job_info['rating'] = company_details[1].text
    except:
        job_info['rating'] = np.nan

    try: 
        job_info['reviews'] = company_details[2].text
    except:
        job_info['reviews'] = np.nan

    other_details = each_job.find("div", attrs={"class": "row3"}).find_all("span", attrs={})

    try:    
        job_info['experience'] = other_details[2].text.strip()
    except:
        job_info['experience'] = np.nan

    try:    
        job_info['salary'] = other_details[4].text.strip()
    except:
        job_info['salary'] = np.nan

    try:
        job_info['location'] = other_details[6].text.strip()
    except:
        job_info['location'] = np.nan

    try:
        job_info['qualification_required'] = each_job.find("div", attrs={"class": "row4"}).text
    except:
        job_info['qualification_required'] = np.nan

    tags = each_job.find("div", attrs={"class": "row5"}).find_all("li", attrs={"class": "dot-gt tag-li"})

    try:
        job_info['skills'] = ",".join([tag.text.strip() for tag in tags])
    except:
        job_info['skills'] = np.nan

    try:
        job_info['day_posted'] = each_job.find("div", attrs={"class": "row6"}).text
    except:
        job_info['day_posted'] = np.nan

    each_df = pd.DataFrame(job_info, index=[0])
    df = pd.concat((df, each_df), ignore_index=True)
"""

# %%
df
